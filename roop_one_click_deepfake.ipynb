# %% [markdown]
# #Clone roop repo and install dependencies

# %% [markdown]
# #download model

# %%
# !git clone https://github.com/s0md3v/roop.git
# %cd roop
# !pip install -r requirements.txt
# Out:
# c:\Users\QuangThai\Desktop\roop-deepfake\roop
# Cloning into 'roop'...
# C:\Users\QuangThai\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %cd roop
# %pip install -r requirements.txt
# Out:
# c:\Users\QuangThai\Desktop\roop-deepfake\roop
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Ignoring tkinterdnd2-universal: markers 'sys_platform == "darwin" and platform_machine == "arm64"' don't match your environment
# Ignoring onnxruntime: markers 'python_version != "3.9" and sys_platform == "darwin" and platform_machine != "arm64"' don't match your environment
# Ignoring onnxruntime-coreml: markers 'python_version == "3.9" and sys_platform == "darwin" and platform_machine != "arm64"' don't match your environment
# Ignoring onnxruntime-silicon: markers 'sys_platform == "darwin" and platform_machine == "arm64"' don't match your environment
# ...
#   Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# ...
#   Using cached opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached onnx-1.14.0-cp311-cp311-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached psutil-5.9.5-cp36-abi3-win_amd64.whl.metadata (21 kB)
# ...

# %%
pip install pandoc
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33290 sha256=0c5e90f8eb7a4e25a668e3cf52dc588da4303ca41b28e2f5a33a3c105200f11d
#   Stored in directory: c:\users\quangthai\appdata\local\pip\cache\wheels\1c\a9\c4\6254542c4e8202d52fcd69798d2507aaad1f2a4bb60f2f0fea
# Successfully built pandoc
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip setuptools
# Out:
# ...
#   Using cached setuptools-72.1.0-py3-none-any.whl.metadata (6.6 kB)
# Using cached setuptools-72.1.0-py3-none-any.whl (2.3 MB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 71.1.0
#     Uninstalling setuptools-71.1.0:
#       Successfully uninstalled setuptools-71.1.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install wheel
# %pip install setuptools
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install insightface
# Out:
# ...
#   Using cached insightface-0.7.3.tar.gz (439 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached scikit_image-0.24.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached albumentations-1.4.12-py3-none-any.whl.metadata (38 kB)
# ...
#   Using cached prettytable-3.10.2-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# ...
#   Using cached albucore-0.0.13-py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# ...

# %%
pip install Cython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install insightface --no-cache-dir -v
# Out:
# Using pip 24.2 from c:\Users\QuangThai\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip (python 3.11)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Obtaining dependency information for scikit-image from https://files.pythonhosted.org/packages/50/b2/d5e97115733e2dc657e99868ae0237705b79d0c81f6ced21b8f0799a30d1/scikit_image-0.24.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for easydict from https://files.pythonhosted.org/packages/05/ec/fa6963f1198172c2b75c9ab6ecefb3045991f92f75f5eb41b6621b198123/easydict-1.13-py3-none-any.whl.metadata
# ...

# %%
# !git clone https://github.com/deepinsight/insightface.git
# %cd insightface
# !python setup.py install
# Out:
# c:\Users\QuangThai\Desktop\roop-deepfake\roop\insightface
# Cloning into 'insightface'...
# C:\Users\QuangThai\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# python: can't open file 'c:\\Users\\QuangThai\\Desktop\\roop-deepfake\\roop\\insightface\\setup.py': [Errno 2] No such file or directory

# %%
# %pip install insightface
# Out:
# ...
#   Using cached insightface-0.7.3.tar.gz (439 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached scikit_image-0.24.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached albumentations-1.4.12-py3-none-any.whl.metadata (38 kB)
# ...
#   Using cached prettytable-3.10.2-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# ...
#   Using cached albucore-0.0.13-py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# ...

# %%
pip install customtkinter
# Out:
# ...
#
# ...

# %%
# !wget https://huggingface.co/ezioruan/inswapper_128.onnx/resolve/main/inswapper_128.onnx -O inswapper_128.onnx
# !mkdir models
# !mv inswapper_128.onnx ./models
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# #Deepfake

# %%
# !python run.py --target "D:\Tài liệu UIT\OneDrive - Trường ĐH CNTT - University of Information Technology\Ảnh\Cuộn Camera\WIN_20240726_13_58_37_Pro.mp4" --output-video-quality 80 --source "D:\Tài liệu UIT\OneDrive - Trường ĐH CNTT - University of Information Technology\Ảnh\Cuộn Camera\WIN_20240802_11_37_29_Pro.jpg" -o "D:\Tài liệu UIT\OneDrive - Trường ĐH CNTT - University of Information Technology\Ảnh\Cuộn Camera\WIN_20240726_13_58_37_Pro_fake.mp4" --execution-provider cuda --frame-processor face_swapper face_enhancer
# Out:
# Traceback (most recent call last):
#   File "c:\Users\QuangThai\Desktop\roop-deepfake\roop\run.py", line 3, in <module>
#     from roop import core
#   File "c:\Users\QuangThai\Desktop\roop-deepfake\roop\roop\core.py", line 20, in <module>
#     import roop.ui as ui
#   File "c:\Users\QuangThai\Desktop\roop-deepfake\roop\roop\ui.py", line 12, in <module>
#     from roop.face_analyser import get_one_face
#   File "c:\Users\QuangThai\Desktop\roop-deepfake\roop\roop\face_analyser.py", line 7, in <module>
#     from roop.typing import Frame, Face
#   File "c:\Users\QuangThai\Desktop\roop-deepfake\roop\roop\typing.py", line 3, in <module>
#     from insightface.app.common import Face
# ModuleNotFoundError: No module named 'insightface.app'
